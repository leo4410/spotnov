# %%
import geopandas as gpd

# %%
gpd.read_file("../data/100058.csv")
# Out:
#     Laufnummer Kategorie Bezeichnung   Wochentag Übertretungs-Wochentagnummer  \
# 0      1761051         Personenwagen   6 Freitag                            6
# 1      1763333         Personenwagen  3 Dienstag                            3
# 2      1763338         Personenwagen  3 Dienstag                            3
# 3      1765239         Personenwagen   7 Samstag                            7
# 4      1765241         Personenwagen   7 Samstag                            7
# ..         ...                   ...         ...                          ...
# 116    1792006         Personenwagen   7 Samstag                            7
# 117    1792672         Personenwagen    2 Montag                            2
# 118    1793101         Personenwagen  4 Mittwoch                            4
# 119    1793102         Personenwagen  4 Mittwoch                            4
# 120    1793697         Personenwagen   7 Samstag                            7
#
# ...
